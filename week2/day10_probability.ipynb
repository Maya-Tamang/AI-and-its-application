# %% [markdown]
# #Probility Basics for AI

# %% [markdown]
# #Theoretical Probability

# %%
#Declaring fav and total outcome for rolling dice 1 om a die!
favourable_outcome=1
total_outcome=6

probability=favourable_outcome/total_outcome
print(probability)
# Out:
# 0.16666666666666666

# %% [markdown]
# #Task1:
# Calculate the theoretical probability of drawing a red card from a standard card deck of 52 cards(26 red cards).print the result.

# %% [markdown]
# #Experimental Probability

# %%
import random

trials=100
heads=0
for _ in range(trials):
  if random.choice(["Heads","Tails"])=="Heads":
    heads+=1
probability=heads/trials
print(probability)
# Out:
# 0.51

# %% [markdown]
# #Conditional Probability
#
# #Task 1:
#
# A standard deck has 52 cards. There are 12 face cards (Jack, Queen, King – 4 of each).What is the probability that a card is a King given that it’s a face card?

# %%
face_card=12
king_card=4
probability=king_card/face_card
print(probability)
# Out:
# 0.3333333333333333

# %% [markdown]
# #Task2:
# Out of 100 days, it rained on 30 days.On 25 of those rainy days, a person carried an umbrella. What is the probability that they carried an umbrella given that it was raining?

# %%
total_rainyday=30
total_carryumbrella=25
probability=total_carryumbrella/total_rainyday
print(probability)
# Out:
# 0.8333333333333334

# %% [markdown]
# #Task 3:
# Out of 80 students, 50 studied for the exam. Out of those 50, 45 passed. What is the probability a student passed given that they studied?

# %%
total_student=80
studied_student=50
pass_student=45
probability_pass=pass_student/studied_student
print(probability_pass)
# Out:
# 0.9

# %% [markdown]
# #Addition Rule

# %%
#Mutually Exclusive events
prob_even=3/6
prob_1=1/6

prob_even_or_one=prob_even+prob_1
print(prob_even_or_one)
# Out:
# 0.6666666666666666

# %% [markdown]
# #Class Task4:
# Calculate the probability of drawing a heart or club from a deck(13 hearts,13 clubs,mutually exclusive).print the result

# %%
total_card=52
prob_heart=13/52
prob_club=13/52
prob_heart_or_club=prob_heart+prob_club
print(prob_heart_or_club)
# Out:
# 0.5

# %% [markdown]
# #Multiplication Rule(Independent Event)
#
# Note!! For independent events,the probability of both occuring is the product of thier probability

# %%
prob_head=0.5
prob_two_heads=prob_head*prob_head

print(prob_two_heads)
# Out:
# 0.25

# %% [markdown]
# #Task 5:
#  Calculate the probability of rolling a 6 twice in a row with six-sided

# %%
prob_six=1/6
prob_twice_six=prob_six*prob_six
print(prob_twice_six)
# Out:
# 0.027777777777777776

# %%
prob_head=0.5
prob_7=1/12
prob_head_and_7=prob_head*prob_7
print(prob_head_and_7)
# Out:
# 0.041666666666666664

# %% [markdown]
# #Dependent Event

# %%
#lets calculate the probability of drawing two aces without replacement from a deck of 52 cards
total_carda=52
ace_cards=4

prob_first_ace=ace_cards/total_cards
prob_second_ace=(ace_cards-1)/(total_cards-1)

prob_two_aces=prob_first_ace*prob_second_ace
print(prob_two_aces)
# Out:
# 0.004524886877828055

# %% [markdown]
# #Task 6:
# Calculate the probability of drawing two red cards without replacement from deck(26 red cards,52 total cards).print result.

# %%
total_cards=52
red_cards=26

prob_first_red=red_cards/total_cards
prob_second_red=(red_cards-1)/(total_cards-1)

prob_two_red=prob_first_red*prob_second_red
print(prob_two_red)
# Out:
# 0.24509803921568626

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. Theoretical probability of rolling < 3 on a 6-sided die
favorable = 2
total = 6
prob_1 = favorable / total
print(f"Theoretical probability of rolling < 3: {prob_1:.2f}")
# Out:
# Theoretical probability of rolling < 3: 0.33

# %%
# 2. Simulate 200 coin flips and calculate experimental probability of tails
import random
flips = 200
tails = sum(1 for _ in range(flips) if random.choice(['H', 'T']) == 'T')
prob_2 = tails / flips
print(f"Experimental probability of tails in 200 flips: {prob_2:.2f}")
# Out:
# Experimental probability of tails in 200 flips: 0.54

# %%
# 3. Conditional probability: P(Queen | Face card)
total_face_cards = 12
queens = 4
prob_3 = queens / total_face_cards
print(f" Conditional probability of queen given face card: {prob_3:.2f}")
# Out:
#  Conditional probability of queen given face card: 0.33

# %%
 #4. Probability of rolling a 3 or 5 (mutually exclusive)
prob_4 = (1/6) + (1/6)
print(f"Probability of rolling 3 or 5: {prob_4:.2f}")
# Out:
# Probability of rolling 3 or 5: 0.33

# %%
# 5. Probability of red then black card without replacement
prob_red = 26 / 52
prob_black_after_red = 26 / 51
prob_5 = prob_red * prob_black_after_red
print(f" Probability of red then black without replacement: {prob_5:.4f}")
# Out:
#  Probability of red then black without replacement: 0.2549
